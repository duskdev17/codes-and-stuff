# %%
x = min(20, 10, 34)
y = max(21, 43, 12)

print(x)
print(y)
# Out:
# 10
# 43

# %%
x1 = abs(-32.21)

print(x1)
# Out:
# 32.21

# %%
x2 = pow(2, 5)

print(x2)
# Out:
# 32

# %%
import math

x3 = math.sqrt(64)
print(x3)
# Out:
# 8.0

# %%
#ceil and floor - makes the number round as per needed
import math

x4 = math.ceil(2.4)
x5 = math.floor(10.4)

print(x4)
print(x5)
# Out:
# 3
# 10

# %%
import math

x6 = math.pi

print(x6)
# Out:
# 3.141592653589793

# %%
import math

x7 = math.cos(2)
x8 = math.factorial(3)
x9 = math.hypot(2)
x10 = math.radians(60)


print(x7)
print(x8)
print(x9)
print(x10)
# Out:
# -0.4161468365471424
# 6
# 2.0
# 0.17453292519943295

# %%
import math 

x = math.pi

print(x)
# Out:
# 3.141592653589793

# %%
import math

a = math.factorial(4)

print(a)
# Out:
# 24

# %%
import math

b = math.degrees(2)

print(b)
# Out:
# 114.59155902616465
